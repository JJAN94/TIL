# %% [markdown]
# ### 데이터 전처리 수행.
# * 학습/검증/테스트 데이터 세트로 나누고 원-핫 인코딩 수행

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

import random as python_random
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10

# seed 를 설정해서 학습시마다 동일한 결과 유도. 불행히도 의도한 대로 동작하지 않음. 
def set_random_seed(seed_value):
    np.random.seed(seed_value)
    python_random.seed(seed_value)
    tf.random.set_seed(seed_value)

# 0 ~ 1사이값의 float32로 변경하는 함수
def get_preprocessed_data(images, labels):
    
    # 학습과 테스트 이미지 array를 0~1 사이값으로 scale 및 float32 형 변형. 
    images = np.array(images/255.0, dtype=np.float32)
    labels = np.array(labels, dtype=np.float32)
    
    return images, labels

# 0 ~ 1사이값 float32로 변경하는 함수 호출 한 뒤 OHE 적용 
def get_preprocessed_ohe(images, labels):
    images, labels = get_preprocessed_data(images, labels)
    # OHE 적용 
    oh_labels = to_categorical(labels)
    return images, oh_labels

# 학습/검증/테스트 데이터 세트에 전처리 및 OHE 적용한 뒤 반환 
def get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021):
    # 학습 및 테스트 데이터 세트를  0 ~ 1사이값 float32로 변경 및 OHE 적용. 
    train_images, train_oh_labels = get_preprocessed_ohe(train_images, train_labels)
    test_images, test_oh_labels = get_preprocessed_ohe(test_images, test_labels)
    
    # 학습 데이터를 검증 데이터 세트로 다시 분리
    tr_images, val_images, tr_oh_labels, val_oh_labels = train_test_split(train_images, train_oh_labels, test_size=valid_size, random_state=random_state)
    
    return (tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels ) 


# random seed는 2021로 고정.
set_random_seed(2021)
# CIFAR10 데이터 재 로딩 및 Scaling/OHE 전처리 적용하여 학습/검증/데이터 세트 생성. 
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
(tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels) = \
    get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021)

print(tr_images.shape, tr_oh_labels.shape, val_images.shape, val_oh_labels.shape, test_images.shape, test_oh_labels.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (42500, 32, 32, 3) (42500, 10) (7500, 32, 32, 3) (7500, 10) (10000, 32, 32, 3) (10000, 10)

# %%
IMAGE_SIZE = 32

# %% [markdown]
# ### 모델 생성 함수 생성

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

def create_model(verbose=False):
    input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    #x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=2)(x)

    x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=2)(x)

    # cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
    x = Flatten(name='flatten')(x)
    x = Dropout(rate=0.5)(x)
    x = Dense(300, activation='relu', name='fc1')(x)
    x = Dropout(rate=0.3)(x)
    output = Dense(10, activation='softmax', name='output')(x)

    model = Model(inputs=input_tensor, outputs=output)
    
    if verbose:
        model.summary()
    
    return model

# %%
create_model(verbose=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  activation_4 (Activation)   (None, 16, 16, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 8, 8, 128)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 300)               614700
#
#  dropout_1 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 906,254
# Trainable params: 905,486
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# ### Learning Rate와 Early Stopping을 위한 Callback 생성
# * Learning rate 동적 변경은 ReduceLROnPlateau,  모델 Ealry Stopping은 EarlyStopping Callback을 이용.

# %%
# ModelCheckpoint를 동작시키기 전에 기존 저장된 모델은 모두 삭제 
# !rm *.hdf5
# Out:
# rm: cannot remove '*.hdf5': No such file or directory

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = create_model()
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# validation loss가 향상되는 모델만 저장.
mcp_cb = ModelCheckpoint(filepath='./weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss', 
                         save_best_only=True, save_weights_only=True, mode='min', period=1, verbose=0)

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[mcp_cb, rlr_cb, ely_cb] )
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 1329/1329 [==============================] - 29s 20ms/step - loss: 1.5631 - accuracy: 0.4352 - val_loss: 1.3407 - val_accuracy: 0.4972 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 1.1056 - accuracy: 0.6063 - val_loss: 0.9843 - val_accuracy: 0.6485 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.9246 - accuracy: 0.6759 - val_loss: 1.0312 - val_accuracy: 0.6433 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.8100 - accuracy: 0.7174 - val_loss: 0.8656 - val_accuracy: 0.6881 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.7203 - accuracy: 0.7534 - val_loss: 0.6814 - val_accuracy: 0.7728 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 24s 18ms/step - loss: 0.6516 - accuracy: 0.7757 - val_loss: 0.6949 - val_accuracy: 0.7629 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.5913 - accuracy: 0.7977 - val_loss: 0.6248 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 24s 18ms/step - loss: 0.5459 - accuracy: 0.8151 - val_loss: 0.6515 - val_accuracy: 0.7809 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 24s 18ms/step - loss: 0.4953 - accuracy: 0.8322 - val_loss: 0.5411 - val_accuracy: 0.8179 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 24s 18ms/step - loss: 0.4569 - accuracy: 0.8444 - val_loss: 0.5316 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.4188 - accuracy: 0.8581 - val_loss: 0.5966 - val_accuracy: 0.8055 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.3909 - accuracy: 0.8676 - val_loss: 0.7178 - val_accuracy: 0.7824 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 26s 19ms/step - loss: 0.3581 - accuracy: 0.8768 - val_loss: 0.5424 - val_accuracy: 0.8309 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.3336 - accuracy: 0.8859 - val_loss: 0.6699 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 15/30
# 1326/1329 [============================>.] - ETA: 0s - loss: 0.3137 - accuracy: 0.8920
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.3140 - accuracy: 0.8919 - val_loss: 0.6238 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.2107 - accuracy: 0.9282 - val_loss: 0.4898 - val_accuracy: 0.8555 - lr: 2.0000e-04
# Epoch 17/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.1669 - accuracy: 0.9414 - val_loss: 0.5266 - val_accuracy: 0.8501 - lr: 2.0000e-04
# Epoch 18/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.1513 - accuracy: 0.9473 - val_loss: 0.5184 - val_accuracy: 0.8585 - lr: 2.0000e-04
# Epoch 19/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.1407 - accuracy: 0.9510 - val_loss: 0.5313 - val_accuracy: 0.8576 - lr: 2.0000e-04
# Epoch 20/30
# 1329/1329 [==============================] - 24s 18ms/step - loss: 0.1295 - accuracy: 0.9548 - val_loss: 0.5526 - val_accuracy: 0.8556 - lr: 2.0000e-04
# Epoch 21/30
# 1328/1329 [============================>.] - ETA: 0s - loss: 0.1195 - accuracy: 0.9585
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.1195 - accuracy: 0.9585 - val_loss: 0.5959 - val_accuracy: 0.8547 - lr: 2.0000e-04
# Epoch 22/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.0937 - accuracy: 0.9664 - val_loss: 0.5708 - val_accuracy: 0.8577 - lr: 4.0000e-05
# Epoch 23/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.0933 - accuracy: 0.9676 - val_loss: 0.5799 - val_accuracy: 0.8577 - lr: 4.0000e-05
# Epoch 24/30
# 1329/1329 [==============================] - 26s 20ms/step - loss: 0.0899 - accuracy: 0.9684 - val_loss: 0.5834 - val_accuracy: 0.8603 - lr: 4.0000e-05
# Epoch 25/30
# 1329/1329 [==============================] - 25s 19ms/step - loss: 0.0872 - accuracy: 0.9690 - val_loss: 0.5902 - val_accuracy: 0.8587 - lr: 4.0000e-05
# Epoch 26/30
# 1328/1329 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9719
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1329/1329 [==============================] - 26s 19ms/step - loss: 0.0823 - accuracy: 0.9719 - val_loss: 0.5925 - val_accuracy: 0.8596 - lr: 4.0000e-05
# Epoch 00026: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6137 - accuracy: 0.8527
# [0.6136704087257385, 0.8526999950408936]

# %%
# !ls -lia
# Out:
# total 28816
# 2884489 drwxr-xr-x 1 root root    4096 Feb 15 05:22 .
# 3164439 drwxr-xr-x 1 root root    4096 Feb 15 04:56 ..
# 3539133 drwxr-xr-x 4 root root    4096 Feb  1 14:31 .config
# 2884490 drwxr-xr-x 1 root root    4096 Feb  1 14:32 sample_data
# 2490370 -rw-r--r-- 1 root root 3685760 Feb 15 05:15 weights.01-1.34.hdf5
# 2490371 -rw-r--r-- 1 root root 3685760 Feb 15 05:16 weights.02-0.98.hdf5
# 2490372 -rw-r--r-- 1 root root 3685760 Feb 15 05:17 weights.04-0.87.hdf5
# 2490373 -rw-r--r-- 1 root root 3685760 Feb 15 05:17 weights.05-0.68.hdf5
# 2490374 -rw-r--r-- 1 root root 3685760 Feb 15 05:18 weights.07-0.62.hdf5
# 2490375 -rw-r--r-- 1 root root 3685760 Feb 15 05:19 weights.09-0.54.hdf5
# 2490376 -rw-r--r-- 1 root root 3685760 Feb 15 05:19 weights.10-0.53.hdf5
# 2490377 -rw-r--r-- 1 root root 3685760 Feb 15 05:22 weights.16-0.49.hdf5

# %% [markdown]
# ### 최적 weight를 모델로 재 로딩한 다음에 테스트 데이터로 다시 평가

# %%
model = create_model()
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# 모델 weight를 불러오기전에 모델을 미리 만들어줘야한다.
model.load_weights('./weights.16-0.49.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.evaluate(test_images, test_oh_labels)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5047 - accuracy: 0.8475
# [0.5047208070755005, 0.8475000262260437]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_history(history):
    plt.figure(figsize=(8, 4))
    plt.yticks(np.arange(0, 1, 0.05))
    plt.xticks(np.arange(0, 30, 2))
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='valid')
    plt.legend()
    
show_history(history)

# %% [markdown]
# ### 필터의 개수를 증가시켜 테스트
# * Conv Layer의 필터를 기존보다 2배씩 증가
# * 맨 마지막 Conv는 512로 대폭 증가

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

#x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가
x = Conv2D(filters=512, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D(pool_size=2)(x)

# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_20 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_28 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_21 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_22 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_30 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_31 (Activation)  (None, 16, 16, 128)       0
#
#  activation_32 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_23 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_33 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_24 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_34 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_25 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_35 (Activation)  (None, 8, 8, 512)         0
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 512)        0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_8 (Dropout)         (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_9 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 1329/1329 [==============================] - 47s 34ms/step - loss: 2.0569 - accuracy: 0.2320 - val_loss: 1.6358 - val_accuracy: 0.3789 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.5970 - accuracy: 0.3746 - val_loss: 1.4455 - val_accuracy: 0.4437 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.4013 - accuracy: 0.4467 - val_loss: 1.2486 - val_accuracy: 0.5548 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.2571 - accuracy: 0.5201 - val_loss: 0.9732 - val_accuracy: 0.6824 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.1219 - accuracy: 0.5824 - val_loss: 0.8808 - val_accuracy: 0.6925 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.0328 - accuracy: 0.6195 - val_loss: 0.8857 - val_accuracy: 0.7080 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.9124 - accuracy: 0.6757 - val_loss: 0.7939 - val_accuracy: 0.7441 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.7893 - accuracy: 0.7278 - val_loss: 1.2729 - val_accuracy: 0.6243 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.6660 - accuracy: 0.7756 - val_loss: 0.7024 - val_accuracy: 0.7723 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.5628 - accuracy: 0.8147 - val_loss: 0.6220 - val_accuracy: 0.8076 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.4889 - accuracy: 0.8402 - val_loss: 0.7471 - val_accuracy: 0.7713 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.4185 - accuracy: 0.8634 - val_loss: 0.6486 - val_accuracy: 0.8024 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.3593 - accuracy: 0.8823 - val_loss: 0.5547 - val_accuracy: 0.8292 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.3111 - accuracy: 0.8994 - val_loss: 0.5748 - val_accuracy: 0.8420 - lr: 0.0010
# Epoch 15/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.2724 - accuracy: 0.9115 - val_loss: 0.7088 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.2323 - accuracy: 0.9240 - val_loss: 0.5971 - val_accuracy: 0.8368 - lr: 0.0010
# Epoch 17/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.2088 - accuracy: 0.9329 - val_loss: 0.6670 - val_accuracy: 0.8264 - lr: 0.0010
# Epoch 18/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.1840 - accuracy: 0.9403
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.1840 - accuracy: 0.9403 - val_loss: 0.6912 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 19/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0847 - accuracy: 0.9729 - val_loss: 0.5755 - val_accuracy: 0.8713 - lr: 2.0000e-04
# Epoch 20/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0531 - accuracy: 0.9823 - val_loss: 0.6583 - val_accuracy: 0.8712 - lr: 2.0000e-04
# Epoch 21/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0393 - accuracy: 0.9864 - val_loss: 0.7157 - val_accuracy: 0.8713 - lr: 2.0000e-04
# Epoch 22/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 0.7269 - val_accuracy: 0.8693 - lr: 2.0000e-04
# Epoch 23/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9903
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0302 - accuracy: 0.9903 - val_loss: 0.7827 - val_accuracy: 0.8685 - lr: 2.0000e-04
# Epoch 00023: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8679 - accuracy: 0.8592

# %% [markdown]
# ### 맨 마지막 Conv + MaxPooling 대신 맨 마지막 Conv의 Strides를 2로 하여 Feature map 조정

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가하되 이후 MaxPooling을 적용하지 않고 strides는 2로 변경하여 출력 feature map 크기 조정
x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)


# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_26 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_36 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_27 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_37 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_15 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_28 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_39 (Activation)  (None, 16, 16, 128)       0
#
#  activation_40 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_16 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_29 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_30 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_42 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_31 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_43 (Activation)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_10 (Dropout)        (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_11 (Dropout)        (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 1329/1329 [==============================] - 48s 35ms/step - loss: 1.6746 - accuracy: 0.3797 - val_loss: 1.5706 - val_accuracy: 0.4105 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 47s 35ms/step - loss: 1.2250 - accuracy: 0.5573 - val_loss: 1.1648 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.9973 - accuracy: 0.6496 - val_loss: 1.0820 - val_accuracy: 0.6329 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.8550 - accuracy: 0.7052 - val_loss: 0.8211 - val_accuracy: 0.7243 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.7384 - accuracy: 0.7493 - val_loss: 1.0202 - val_accuracy: 0.6748 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.6373 - accuracy: 0.7864 - val_loss: 0.6880 - val_accuracy: 0.7699 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.5436 - accuracy: 0.8179 - val_loss: 0.6025 - val_accuracy: 0.8067 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.4668 - accuracy: 0.8449 - val_loss: 0.6189 - val_accuracy: 0.7948 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.4007 - accuracy: 0.8661 - val_loss: 0.6839 - val_accuracy: 0.7863 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 47s 36ms/step - loss: 0.3428 - accuracy: 0.8851 - val_loss: 0.6782 - val_accuracy: 0.7943 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.2949 - accuracy: 0.9022 - val_loss: 0.7785 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 12/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.2466 - accuracy: 0.9179
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.2466 - accuracy: 0.9179 - val_loss: 0.7445 - val_accuracy: 0.7881 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.1215 - accuracy: 0.9591 - val_loss: 0.5361 - val_accuracy: 0.8707 - lr: 2.0000e-04
# Epoch 14/30
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.0762 - accuracy: 0.9736 - val_loss: 0.5973 - val_accuracy: 0.8625 - lr: 2.0000e-04
# Epoch 15/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0626 - accuracy: 0.9782 - val_loss: 0.6788 - val_accuracy: 0.8643 - lr: 2.0000e-04
# Epoch 16/30
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.0501 - accuracy: 0.9824 - val_loss: 0.6517 - val_accuracy: 0.8697 - lr: 2.0000e-04
# Epoch 17/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.7211 - val_accuracy: 0.8676 - lr: 2.0000e-04
# Epoch 18/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9894
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0327 - accuracy: 0.9894 - val_loss: 0.7880 - val_accuracy: 0.8652 - lr: 2.0000e-04
# Epoch 19/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.7458 - val_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 20/30
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.7848 - val_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 21/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.7915 - val_accuracy: 0.8700 - lr: 4.0000e-05
# Epoch 22/30
# 1329/1329 [==============================] - 46s 35ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.8259 - val_accuracy: 0.8724 - lr: 4.0000e-05
# Epoch 23/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9961
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1329/1329 [==============================] - 47s 35ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.8483 - val_accuracy: 0.8709 - lr: 4.0000e-05
# Epoch 00023: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8913 - accuracy: 0.8622

# %% [markdown]
# ### Global Average Pooling의 적용
# * Global Average Pooling은 피처맵의 가로x세로의 특정 영역을 Sub sampling 않고, 채널별로 평균 값을 추출(Global의 의미가 채널을 뜻함)
# * 충분히 Feature map의 채널수가 많을 경우 이를 적용. 채널수가 적다면 Flatten이 유리.
# * Flatten-> Classification Dense Layer로 이어지면서 많은 파라미터들로 인한 오버피팅 유발 가능성 증대 및 학습 시간 늘어남.
# * 맨 마지막 Feature Map의 채널 수가 충분히 크다면 GlobalAveragePooling2D를 적용하여 Flatten을 제거하는데 더 유리 할 수 있음.  (512정도는 되야 쓸만하다)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

#x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Flatten 대신 Global AveragePooling 을 적용. 
x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.5)(x)
x = Dense(50, activation='relu', name='fc1')(x)
x = Dropout(rate=0.2)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_32 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_44 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_33 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_45 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_34 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_46 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_47 (Activation)  (None, 16, 16, 128)       0
#
#  activation_48 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_35 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_49 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_36 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_50 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_44 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_37 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_51 (Activation)  (None, 4, 4, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  fc1 (Dense)                 (None, 50)                25650
#
#  dropout_13 (Dropout)        (None, 50)                0
#
#  output (Dense)              (None, 10)                510
#
# =================================================================
# Total params: 2,356,848
# Trainable params: 2,354,288
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 1329/1329 [==============================] - 50s 36ms/step - loss: 1.5145 - accuracy: 0.4466 - val_loss: 1.7663 - val_accuracy: 0.4276 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 1.0565 - accuracy: 0.6278 - val_loss: 1.4426 - val_accuracy: 0.5247 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.8562 - accuracy: 0.7044 - val_loss: 0.7817 - val_accuracy: 0.7271 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.7156 - accuracy: 0.7575 - val_loss: 0.9647 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.6115 - accuracy: 0.7932 - val_loss: 0.7513 - val_accuracy: 0.7468 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.5252 - accuracy: 0.8257 - val_loss: 0.7928 - val_accuracy: 0.7580 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.4540 - accuracy: 0.8510 - val_loss: 0.6434 - val_accuracy: 0.7945 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.3934 - accuracy: 0.8693 - val_loss: 0.6099 - val_accuracy: 0.7971 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.3305 - accuracy: 0.8901 - val_loss: 0.6979 - val_accuracy: 0.7927 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.2880 - accuracy: 0.9052 - val_loss: 0.6334 - val_accuracy: 0.8047 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 45s 33ms/step - loss: 0.2393 - accuracy: 0.9222 - val_loss: 0.5856 - val_accuracy: 0.8195 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.2086 - accuracy: 0.9309 - val_loss: 0.6631 - val_accuracy: 0.8077 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.1789 - accuracy: 0.9421 - val_loss: 0.6302 - val_accuracy: 0.8251 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.1513 - accuracy: 0.9508 - val_loss: 0.6658 - val_accuracy: 0.8193 - lr: 0.0010
# Epoch 15/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.1374 - accuracy: 0.9548 - val_loss: 0.6271 - val_accuracy: 0.8316 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.1173 - accuracy: 0.9615 - val_loss: 0.5802 - val_accuracy: 0.8420 - lr: 0.0010
# Epoch 17/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.1074 - accuracy: 0.9646 - val_loss: 0.6485 - val_accuracy: 0.8317 - lr: 0.0010
# Epoch 18/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0958 - accuracy: 0.9687 - val_loss: 0.9366 - val_accuracy: 0.7956 - lr: 0.0010
# Epoch 19/30
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0898 - accuracy: 0.9711 - val_loss: 0.6797 - val_accuracy: 0.8457 - lr: 0.0010
# Epoch 20/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0805 - accuracy: 0.9746 - val_loss: 0.8528 - val_accuracy: 0.8127 - lr: 0.0010
# Epoch 21/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9758
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0742 - accuracy: 0.9758 - val_loss: 0.9150 - val_accuracy: 0.8088 - lr: 0.0010
# Epoch 22/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0279 - accuracy: 0.9919 - val_loss: 0.5819 - val_accuracy: 0.8737 - lr: 2.0000e-04
# Epoch 23/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.6760 - val_accuracy: 0.8727 - lr: 2.0000e-04
# Epoch 24/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.7114 - val_accuracy: 0.8729 - lr: 2.0000e-04
# Epoch 25/30
# 1329/1329 [==============================] - 45s 34ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.7203 - val_accuracy: 0.8749 - lr: 2.0000e-04
# Epoch 26/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9973
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 44s 33ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.7462 - val_accuracy: 0.8728 - lr: 2.0000e-04
# Epoch 00026: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8206 - accuracy: 0.8619

# %% [markdown]
# ### 가중치 규제(Weight Regularizations)
# * 개별 layer별로 tensorflow.keras.regularizers의 l1, l2, l1_l2 를 이용하여 가중치 규제를 적용할 수 있음.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2, l1_l2

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
# 강사님 기준에선 이미지쪽은 규제의 효과를 잘 모르시겠다 함
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00001))(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00001))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가하되 이후 MaxPooling을 적용하지 않고 strides는 2로 변경하여 출력 feature map 크기 조정
x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)


# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', kernel_regularizer=l2(1e-5), name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_38 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_52 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_39 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_53 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_40 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_54 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_55 (Activation)  (None, 16, 16, 128)       0
#
#  activation_56 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_20 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_41 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_57 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_50 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_42 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_58 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_51 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_43 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_59 (Activation)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_14 (Dropout)        (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_15 (Dropout)        (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/30
# 1329/1329 [==============================] - 51s 37ms/step - loss: 1.6808 - accuracy: 0.4015 - val_loss: 1.4284 - val_accuracy: 0.5021 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 1.2393 - accuracy: 0.5776 - val_loss: 1.4448 - val_accuracy: 0.5459 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 50s 37ms/step - loss: 1.0570 - accuracy: 0.6563 - val_loss: 0.9909 - val_accuracy: 0.6912 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.9478 - accuracy: 0.7048 - val_loss: 0.8654 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.8721 - accuracy: 0.7436 - val_loss: 0.8664 - val_accuracy: 0.7565 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 50s 37ms/step - loss: 0.7907 - accuracy: 0.7785 - val_loss: 1.3197 - val_accuracy: 0.6675 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 50s 37ms/step - loss: 0.7427 - accuracy: 0.8074 - val_loss: 0.8612 - val_accuracy: 0.7671 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.6852 - accuracy: 0.8313 - val_loss: 1.0539 - val_accuracy: 0.7249 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.6422 - accuracy: 0.8524 - val_loss: 0.8520 - val_accuracy: 0.7936 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.5978 - accuracy: 0.8747 - val_loss: 0.7753 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.5729 - accuracy: 0.8865 - val_loss: 0.9931 - val_accuracy: 0.7861 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.5487 - accuracy: 0.8999 - val_loss: 0.8752 - val_accuracy: 0.8131 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.5238 - accuracy: 0.9124 - val_loss: 0.8242 - val_accuracy: 0.8295 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.5136 - accuracy: 0.9199 - val_loss: 0.9311 - val_accuracy: 0.8204 - lr: 0.0010
# Epoch 15/30
# 1329/1329 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.9297
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.4976 - accuracy: 0.9297 - val_loss: 0.9017 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.3771 - accuracy: 0.9708 - val_loss: 0.8128 - val_accuracy: 0.8769 - lr: 2.0000e-04
# Epoch 17/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.3301 - accuracy: 0.9827 - val_loss: 0.9074 - val_accuracy: 0.8703 - lr: 2.0000e-04
# Epoch 18/30
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.3082 - accuracy: 0.9869 - val_loss: 0.9382 - val_accuracy: 0.8732 - lr: 2.0000e-04
# Epoch 19/30
# 1329/1329 [==============================] - 50s 37ms/step - loss: 0.2934 - accuracy: 0.9892 - val_loss: 0.9154 - val_accuracy: 0.8731 - lr: 2.0000e-04
# Epoch 20/30
# 1329/1329 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.9909
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 49s 37ms/step - loss: 0.2782 - accuracy: 0.9909 - val_loss: 0.9160 - val_accuracy: 0.8756 - lr: 2.0000e-04
# Epoch 00020: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.9450 - accuracy: 0.8680
