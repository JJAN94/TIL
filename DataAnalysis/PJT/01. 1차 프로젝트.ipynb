# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 상반기 주유소 판매 데이터 불러오기
first = pd.read_csv('../data/상반기 주유소 판매가격.csv', encoding = 'cp949')
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
second = pd.read_csv('../data/하반기 주유소 판매가격.csv', encoding = 'cp949')
second
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
# 상반기 판매가격 데이터 프레임 결측치 조회

first.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 하반기 판매가격 데이터 프레임 결측치 조회

second.isnull().sum()
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %% [markdown]
# # 2. 데이터 결합

# %%
# 상반기와 하반기 데이터를 상하로 결합
df = pd.concat([first,second])
df
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %% [markdown]
# # 3. 데이터 가공 및 분석

# %%
# 데이터 프레임 정보 조회

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181714 entries, 0 to 91123
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 16.6+ MB

# %%
# 상표 컬럼의 고유값 조회

df['상표'].unique()
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
# 지역 컬럼의 고유값 조회

df['지역'].unique()
# Out:
# array(['서울 강남구', '서울 강동구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구',
#        '서울 구로구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동대문구', '서울 동작구',
#        '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성동구', '서울 성북구', '서울 송파구',
#        '서울 양천구', '서울 영등포구', '서울 용산구', '서울 은평구', '서울 종로구', '서울 중구',
#        '서울 중랑구'], dtype=object)

# %%
# 지역 컬럼의 값을 이용하여 시와 구를 분리

df['시'] = df['지역'].str.split(' ').str[0]
df['구'] = df['지역'].str.split(' ').str[1]
df
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유   시    구
# ...

# %%
# 시 컬럼의 서울을 서울특별시로 변환

df['시']='서울특별시' 
df.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구
# 0   1673  1465  1365     0  서울특별시  강남구
# 1   1673  1465  1365     0  서울특별시  강남구
# 2   1673  1465  1365     0  서울특별시  강남구
# 3   1673  1465  1365     0  서울특별시  강남구
# 4   1673  1465  1365     0  서울특별시  강남구

# %%
# 기간 컬럼을 datetime 형식으로 변경

df['기간'] = pd.to_datetime(df['기간'], format='%Y%m%d')
df.head()

# astype 형식으로 변경하기

# df['기간']= df['기간'].astype('datetime64[ns]', format='%Y%m%d')

# # df.info()
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구
# 0   1673  1465  1365     0  서울특별시  강남구
# 1   1673  1465  1365     0  서울특별시  강남구
# 2   1673  1465  1365     0  서울특별시  강남구
# 3   1673  1465  1365     0  서울특별시  강남구
# 4   1673  1465  1365     0  서울특별시  강남구

# %%
# 기간 컬럼에서 dt 타입을 이용하여 년, 월, 일, 요일 컬럼 생성

import datetime as dt

df['기간'] = pd.to_datetime(df['기간'])
df['년'] = df['기간'].dt.year
df['월'] = df['기간'].dt.month
df['일'] = df['기간'].dt.day
df['요일'] = df['기간'].dt.strftime('%A')
df['요일(number)'] = df['기간'].dt.strftime('%w')
df['주차'] = df['기간'].dt.strftime('%W')
df.head()
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일 요일(number)  주차
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday          2  00
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday          3  00
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday          4  00
# 3   1673  1465  1365     0  서울특별시  강남구  2019  1  4     Friday          5  00
# 4   1673  1465  1365     0  서울특별시  강남구  2019  1  5   Saturday          6  00

# %%
# 휘발유 가격이 비싼 5개 판매가격을 출력하세요.

df.sort_values(by=['휘발유'], ascending=False).head()
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 86620  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 86626  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 86627  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 86621  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 86622  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#         휘발유    경유  실내등유      시   구     년   월   일         요일 요일(number)  주차
# 86620  2356  2196     0  서울특별시  중구  2019   9  24    Tuesday          2  38
# 86626  2356  2196     0  서울특별시  중구  2019   9  30     Monday          1  39
# 86627  2356  2196     0  서울특별시  중구  2019  10   1    Tuesday          2  39
# 86621  2356  2196     0  서울특별시  중구  2019   9  25  Wednesday          3  38
# 86622  2356  2196     0  서울특별시  중구  2019   9  26   Thursday          4  38

# %% [markdown]
# # 4. 데이터 전략 개요

# %% [markdown]
# * 의견 취합
# * 방향성 정리

# %% [markdown]
# ### 기간별 유종별 분석
#
#     1-0. 고급휘발유 전처리
#     1-1. 요일별 유종별 가격 변동
#     1-2. 주간별(연간) 유종별 가격 변동
#     1-3. 월별 유종별 가격 변동
#
#
#
# ###  구(區)별 분석
#
#     2-1. 구별, 유종별 가격 확인
#     2-2. 구별, 특정 회사별 가격
#     2-3. 구별, 주유소 밀집도(개수)
#     2-4. 구별, 셀프주유소 여부

# %% [markdown]
# ##  기간별 유종별 분석

# %% [markdown]
# ### 고급휘발유 전처리
#
# 고급휘발유에 0값이 많아 우선 전처리

# %%
# 0 값 그대로 보여주기
plt.subplot(1,2,1)
sns.kdeplot(df['고급휘발유'])
plt.tight_layout()


# 0값을 중앙값으로 변경해서 보여주기 
plt.subplot(1,2,2)
sns.kdeplot(df[df['고급휘발유'] != 0]['고급휘발유'])
median_value1 = df[df['고급휘발유'] != 0]['고급휘발유'].median() # 고급휘발유의 중앙값
print('중앙값 : {}'.format(median_value1))
plt.show()
# Out:
# 중앙값 : 1807.0

# %%
df.loc[(df.고급휘발유 == 0), '고급휘발유']= median_value1
df # 전처리 완료
# Out:
#              번호      지역             상호              주소         기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
# ...         ...     ...            ...             ...        ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  GS칼텍스   셀프
#
# ...

# %% [markdown]
# ### 요일별 유종별 가격 변동
#
#     pointplot 사용이유 : 기간의 연속성을 표현하기 위하여 선택
#
#     ※ 고급휘발유는 토요일이 가장 가격이 높은 반면, 휘발유와 경유는 월, 화가 높았다.
#
#
#
#    * 결과 :
#
#     휘발유, 경유는 한 주가 시작되는 월 ~ 화에 기름값이 비싸고, 고급휘발유는 토요일이 상대적으로 비싼 경향을 보여준다.
#
#
#
#    * 해석 :
#
#     1. 고급휘발유는 주로 고급 차를 많이 사용하니, 주말에 많이 사용 , 휘발유, 경유는 비싸도 많이 써야해서 라고 오르지 않는가?
#     2. 수요일이 대체적으로 기름값이 싸다. 수요일날 주유하는 것을 권장

# %%
a = df.pivot_table(index=['요일(number)'], values=['휘발유', '고급휘발유', '경유']).sort_values('요일(number)')


plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
sns.pointplot(x=a.index, y=a['고급휘발유'],color='lime')
plt.grid()

plt.xticks(rotation=45)
plt.subplot(1,3,2)
sns.pointplot(x=a.index, y=a['휘발유'],color="orangered")
plt.grid()

plt.xticks(rotation=45)
plt.subplot(1,3,3)
sns.pointplot(x=a.index, y=a['경유'])
plt.grid()

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# 0은 일요일 ~ 6 토요일
# 결과 : 고급휘발유는 토요일이 가장 가격이 높은 반면, 휘발유와 경유는 월, 화가 높았다.
# 해석 : 대체적으로 수요일이 가장 저렴했다 , 수요일에 주유하는 것을 권장!

# %% [markdown]
# ### 주간별(연간) 유종별 가격 변동
#
#
# 1. 국제유가에 대한 생각이 없는 상태에서의 해석
#
#         3월부터 국내 소비량의 증가로 값이 상승하는 것이 아닌가?
#
#
#
# 2. 국제유가가 국내유가에 반영되기까지 3주정도 걸린다.
#
#         그 이유는 정유사에서 오일을 구매하기 까지의 2-3주정도의 term이 있기에 구내 유가에 반영되기 까지 3주정도가 생긴다.
#         (단, 국내유가는 80%가 세금이기 때문에 국제유가 외에 변수가 있는 것은 배제하고 생각하였다.)
#
#
# → 국제 유가 관련 외부 데이터를 취합하면, 국내 유가가 국제 유가로부터 영향을 받아 변화하는 양상을 확인할 수 있을 것으로 보인다.

# %%
c = df.pivot_table(index=['주차'], values=['고급휘발유', '휘발유', '경유']).sort_values('주차')
plt.figure(figsize=(14,20))
plt.subplot(3,1,1)
#sns.pointplot(x=a.index, y=a['고급휘발유'])
plt.plot(c.index,c['고급휘발유'], color='lime')
plt.title('고급휘발유')
plt.grid()
plt.xticks(rotation=45)
plt.yscale('linear')

plt.subplot(3,1,2)
#sns.pointplot(x=a.index, y=a['휘발유'])
plt.plot(c.index,c['휘발유'],color="orangered")
plt.title('휘발유')
plt.grid()
plt.xticks(rotation=45)


plt.subplot(3,1,3)
#sns.pointplot(x=a.index, y=a['경유'])
plt.plot(c.index,c['경유'])
plt.title('경유')
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 월별 유종별 가격 변동
#
#
# pointplot 사용이유 : 월간의 연속성을 표현하기 위하여 선택

# %%
b = df.pivot_table(index=['월'], values=['휘발유', '고급휘발유', '경유']).sort_values('월')
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.grid()

sns.pointplot(x=b.index, y=b['고급휘발유'],color='lime')
plt.xticks(rotation=45)
plt.subplot(1,3,2)
plt.grid()

sns.pointplot(x=b.index, y=b['휘발유'],color="orangered")
plt.xticks(rotation=45)
plt.subplot(1,3,3)
plt.grid()

sns.pointplot(x=b.index, y=b['경유'])
plt.xticks(rotation=45)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 구(區)별 분석

# %% [markdown]
# ###  구별, 유종별 가격 확인
#
#
#
#     결과 : 용산구, 종로, 중구의 가격이 높다.
#
#     의문 : 주유소의 갯수가 적어서 가격 측정이 높지 않을까?
#            지리적 요인이 적용하지 않았을까(용산구의경우, 언덕이 많음)?
#            땅값이 기름 가격에 영향이 있지 않을까?
#
#     → 주유소가 입지될 수 있는 조건이 어려운 지역이다라는 공통점이 있음.
#       지리적 위치로 인하여 도심에 위치한 차량통행량이 많은 곳 일 수도 있음
#       유가가 높은 3~4개 구들은 지리적으로 도심에 위치한 구이거나 차량 총행량이 많은 구임을 알아볼 수 있었다.

# %%
plt.figure(figsize=(10,8))
plt.subplot(3,1,1)
sns.barplot(x=df['구'], y=df['고급휘발유'])
plt.ylim((1600,2250)) # y축만 구간(1600~2500)설정
plt.xticks(rotation=45)
plt.grid()

plt.subplot(3,1,2)
sns.barplot(x=df['구'], y=df['휘발유'])
plt.ylim((1000,2050))
plt.xticks(rotation=45)
plt.grid()

plt.subplot(3,1,3)
sns.barplot(x=df['구'], y=df['경유'])
plt.ylim((800,2000))
plt.xticks(rotation=45)
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 구별, 특정 회사별 가격
#
# pointplot 사용이유? 여러가지 상표의 가격을 한 눈에 비교하기 쉬워서 선택

# %%
plt.figure(figsize=(14,8))
sns.pointplot(x=df['구'], y=df['고급휘발유'], data=df, hue='상표')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.pointplot(x=df['구'], y=df['휘발유'], data=df, hue='상표')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.pointplot(x=df['구'], y=df['경유'], data=df, hue='상표')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# * 결과 :
#
#     알뜰 주유소가 대체적으로 저렴하다.\
#     한 유종의 가격이 높은 구에서는 다른 유종의 가격도 높았다.\
#     Gs칼텍스, 현대오일뱅크는 각 구마다 가격 편차가 크다.

# %% [markdown]
# #####  고급휘발유

# %%
a=df['구'].unique()

k = df.pivot_table(index=['구','상표'], values=['고급휘발유', '휘발유','경유'] )
plt.figure(figsize=(15,15))
plt.title('지역별 상표-고급휘발유 가격')
for i, j in enumerate(a) :
    plt.subplot(5,5,i+1)
    plt.xticks(rotation=45)
    kk=k.loc[j]
    plt.bar(kk.index, kk['고급휘발유'], width=0.4, color = 'c')
    plt.ylim((1100,2500))
    plt.title(j)
    plt.tight_layout()

# %% [markdown]
# #####  휘발유

# %%
a=df['구'].unique()

k = df.pivot_table(index=['구','상표'], values=['고급휘발유', '휘발유','경유'])
plt.figure(figsize=(15,15))
plt.title('지역별 상표-고급휘발유 가격')
for i, j in enumerate(a) :
    plt.subplot(5,5,i+1)
    plt.xticks(rotation=45)
    kk=k.loc[j]
    plt.bar(kk.index, kk['휘발유'], width=0.4, color = 'c')
    plt.ylim((1100,2500))
    plt.title(j)
    plt.tight_layout()

# %% [markdown]
# #####  경유

# %%
a=df['구'].unique()

k = df.pivot_table(index=['구','상표'], values=['고급휘발유', '휘발유','경유'])
plt.figure(figsize=(15,15))
plt.title('지역별 상표-고급휘발유 가격')
for i, j in enumerate(a) :
    plt.subplot(5,5,i+1)
    plt.xticks(rotation=45)
    kk=k.loc[j]
    plt.bar(kk.index, kk['경유'], width=0.4, color = 'c')
    plt.ylim((1100,2500))
    plt.title(j)
    plt.tight_layout()

# %% [markdown]
# ### 구별, 주유소 밀집도 (개수)
#
#  * 밀집도를 분석한 이유
#
#      : 구별로 유종별 가격차와 상표별 가격차를 확인해보니, 특정 구(용산, 종로, 중구)에서 계속적으로 높은 가격이 확인되었다.\
#     따라서 우리는 위 특정 구(용산, 종로, 중구)에 주유소 밀집도가 낮지 않을까?라는 가설을 세웠고, 이를 확인하기 위해 아래와 같이 밀집도를 확인해 보았다.
#
#
# <br>
# folium.Map 사용이유? 구의 위치를 나타내 주유소의 밀집도를 보기 좋게 하기 위함

# %%
# 구별 개수 파악

newdf = df.pivot_table(index=['구', '상호'], values=['경유', '휘발유','고급휘발유'])
a = df['구'].unique() #['%s' % str(t) for t in list(df['구'].unique())]
ls = [newdf.loc[i].index.shape[0] for i in a]
new_dict = {'구' : a, '개수' : ls}
new_df = pd.DataFrame(new_dict)
new_df
# new_df['개수'].sum()
# Out:
#        구  개수
# 0    강남구  41
# 1    강동구  17
# 2    강북구  13
# 3    강서구  35
# 4    관악구  18
# 5    광진구  18
# 6    구로구  22
# 7    금천구  13
# 8    노원구  15
# 9    도봉구  19
# 10  동대문구  22
# 11   동작구  10
# 12   마포구  13
# 13  서대문구  16
# 14   서초구  39
# 15   성동구  17
# 16   성북구  23
# 17   송파구  33
# 18   양천구  26
# 19  영등포구  32
# 20   용산구  15
# 21   은평구  18
# 22   종로구   9
# 23    중구  12
# 24   중랑구  16

# %%
#!pip install folium

# %%
import folium
import json

geo_path = '../data/d/municipalities-geo-simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))


center = [37.541, 126.986]
m1 = folium.Map(location=center, zoom_start=10.5)
choropleth = folium.Choropleth(
        geo_data=geo_str,
        data=new_df,
        columns=('구','개수'),
        key_on='feature.properties.name', # name 매칭!
        fill_color='RdBu_r', # B < R
        legend_name='구별 주유소 개수').add_to(m1)
choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'],labels=False)
)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
loca = pd.read_excel('../data/seoul_data.xlsx')
loca1 = loca.pivot_table(index='구', values=['lat', 'lng'])
loca2 = loca1.merge(new_df, on='구')
loca2.head()

center = [37.541, 126.986]
m4 = folium.Map(location=center, zoom_start=10.5)
folium.Choropleth(
        geo_data=geo_str,
        data=new_df,
        columns=('구','개수'),
        key_on='feature.properties.name',
        fill_color='Greens', legend_name='구별 주유소 개수').add_to(m4)

for i in range(25) :
    lat = float(loca2['lat'][i])
    lng = float(loca2['lng'][i])
    ct = [lat, lng]
    folium.CircleMarker(location=[lat, lng], radius=float(loca2['개수'][i]*1.3), popup=loca2['구'][i], color='midnightblue', fill_color='midnightblue').add_to(m4)
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# 1. 강남, 서초에 등록차량 수가 많아 주유소가 밀집되어 있지 않을까?
# 2. 서울을 기준으로 북쪽보다는 남쪽에 더 많은 지역이 있는데, 그 지역에 오고가기 위해  강남이나 서초에 위치한 IC를 지나가는 경우가 많아서, 이 두 구에 주유소가 많은 것으로 보인다.

# %% [markdown]
# ### 구별, 셀프주유소 여부
#
# sns.violinplot 사용이유 ? 셀프주유소, 일반주유소의 유무를 한 눈에 비교하기 위해 사용

# %%
table2=df.groupby(by=['구','셀프여부'])['고급휘발유','휘발유','경유'].agg(['mean']).sort_values(['구','셀프여부'])
table2
# Out:
# <ipython-input-33-084a95feea0c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   table2=df.groupby(by=['구','셀프여부'])['고급휘발유','휘발유','경유'].agg(['mean']).sort_values(['구','셀프여부'])
#                  고급휘발유          휘발유           경유
#                   mean         mean         mean
# 구    셀프여부
# 강남구  셀프    1827.192058  1576.268528  1448.102615
#      일반    1983.967928  1786.282755  1646.033754
# 강동구  셀프    1819.996865  1537.438871  1409.264498
#      일반    1851.155755  1606.627504  1465.948879
# 강북구  셀프    1802.128010  1453.904602  1329.347760
#      일반    1807.000000  1452.644674  1327.915464
# 강서구  셀프    1768.950695  1465.002748  1333.280110
#      일반    1784.382993  1514.729779  1382.034380
# 관악구  셀프    1800.347313  1495.355177  1371.362167
#      일반    1799.591694  1532.186893  1409.064995
# 광진구  셀프    1775.409471  1487.363788  1358.884123
#      일반    1797.285929  1491.843824  1356.324597
# ...

# %%
a = df['구'].unique()
plt.figure(figsize=(10,50))

for i, j in enumerate(a) :
    try:
        plt.subplot(13,2,i+1) # 행, 열 ,번호
        plt.xticks(rotation=45)
        kk = df[df['구']==j].sort_values(by=['셀프여부'])
        sns.violinplot(data=kk, x='구', y="고급휘발유", hue="셀프여부",
                       split=True, inner="quart", linewidth=1,
                       palette={"셀프": "tomato", "일반": ".5"})
        plt.title(j)
        plt.tight_layout()
        
    except:
        sns.violinplot(data=kk, x='구', y="고급휘발유", 
                       split=True, inner="quart", linewidth=1,
                      color=".5")
        plt.title(j)

# %%
a = df['구'].unique()
plt.figure(figsize=(10,50))

for i, j in enumerate(a) :
    try:
        plt.subplot(13,2,i+1)
        plt.xticks(rotation=45)
        kk = df[df['구']==j].sort_values(by=['셀프여부'])
        sns.violinplot(data=kk, x='구', y="휘발유", hue="셀프여부",
                       split=True, inner="quart", linewidth=1,
                       palette={"셀프": "tomato", "일반": ".5"})
        plt.title(j)
        plt.tight_layout()
    except:
        sns.violinplot(data=kk, x='구', y="휘발유", 
                       split=True, inner="quart", linewidth=1,
                      color=".5")
        plt.title(j)

# %%
a = df['구'].unique()
plt.figure(figsize=(10,50))

for i, j in enumerate(a) :
    try:
        plt.subplot(13,2,i+1)
        plt.xticks(rotation=45)
        kk = df[df['구']==j].sort_values(by=['셀프여부'])
        sns.violinplot(data=kk, x='구', y="경유", hue="셀프여부",
                       split=True, inner="quart", linewidth=1,
                       palette={"셀프": "tomato", "일반": ".5"})
        plt.title(j)
        plt.tight_layout()
    except:
        sns.violinplot(data=kk, x='구', y="경유", 
               split=True, inner="quart", linewidth=1,
              color=".5")
        plt.title(j)

# %% [markdown]
# 셀프주유소가 일반주유소보다 더 저렴 할 것이라는 가설을 세운 후 확인,\
# 셀프주유소보다 일반주유소가 대체적으로 금액이 높은 양상을 보였으며\
# 용산구, 중구, 마포구는 셀프주유소가 없는것을 한눈에 확인 할 수 있었다.

# %% [markdown]
# ## Best Practice & Lesson Learned

# %% [markdown]
# ### Best Practice
# 구별, 주유소 밀집도 (개수)
#
# Folium Map의 지리정보를 이용해 직관적인 시각화를 확인 할 수 있다.
# 실제로 사용한 주유소의 개수 뿐 아니라 유종별 금액 또한 직관적으로 표현 할 수 있다.
#
# 또한,
# 서울이란 특수한 지역에 대해 모르는 사람에게도 지리적 정보를 접근하기 편한 학습성, 또한 정확한 수치가 아니어도 원의 크기로 구별할 수 있는 직관성을 이 시각화에서 발견 할 수 있다.

# %% [markdown]
# ### Lesson Learned
#
# 요일별 유종별 가격 변동
#
#
# 우리가 예상한 것(가설)에 비해, 결과값에는 큰 편차가 없어서, 유의미한 결과값을 내기 위해서는 더 세밀한 분류가 필요하다.
#
#
# 또한, 요일별 차이에 대한 정확한 검증이 필요하다.
# (차이를 뒷 받침 해 줄 수 있는 외부데이터 사용)
