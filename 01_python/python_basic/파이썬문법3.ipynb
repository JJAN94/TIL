# %% [markdown]
# # 파이썬 기본 문법 3

# %% [markdown]
# # 함수란?
# - 반복되는 코드를 묶음으로 효율적인 코드를 작성하도록 해주는 기능
# - 관련된 처리의 모음
# - 파이썬에서는 모든 데이터를 객체라고 부른다.
# - 객체에는 숫자값, 문자열 같은 값뿐만 아니라 다양한 데이터 타입, 클래스, 인스턴스도 포함한다.
# - 파이썬에선 함수도 객체이며, 인수로 받은 데이터 또한 객체이므로 함수 객체를 다른 함수의 인수로 전달하거나 변수에 대입할 수도 있다.
#
# # 목차
# - 기본 함수
# - 파라미터와 아규먼트
# - 리턴
# - \*args, \*\*kwargs
# - docstring
# - scope
# - inner function
# - lambda function
# - Map, Filter, Reduce
# - Decorlator

# %% [markdown]
# ## 1. 기본 함수
# - 함수의 선언과 호출
#
# ```python
# def 함수명(para1, para2, ...):
#     함수에서 실행할 처리
#     return 반환값
# ```
#
# - 인수(argument) : 함수 안의 처리에서 사용할 수 있는 값으로, 인수가 없을 땐 `()`로 쓴다.
# - 함수는 처리 결과를 반환값으로 호출자에게 반환한다.
# - 반환할 필요가 없을 땐 return문을 생략한다.

# %%
point = 83
if point >= 90 :
    print('A')
elif point >= 80 :
    print('B')
else :
    print('C')
# Out:
# B

# %%
# %reset : 현재 주피터 노트북 상 선언된 변수들을 초기화해줌
# %whos : 현재 선언된 변수 리스트를 출력해줌
# %whos
# Out:
# Variable   Type                          Data/Info
# --------------------------------------------------
# calc       function                      <function calc at 0x0000018D51CE28B0>
# data       dict                          n=2
# datas      str                           10 20 30 40 10 20 15
# disp       function                      <function disp at 0x0000018D5492A160>
# echo       function                      <function echo at 0x0000018D51CBA3A0>
# func       function                      <function func at 0x0000018D51BBCD30>
# gv         int                           100
# ls         list                          n=5
# minus      function                      <function minus at 0x0000018D5492A310>
# odd_even   function                      <function odd_even at 0x0000018D51BBC820>
# outer      function                      <function outer at 0x0000018D51CE23A0>
# plus       function                      <function disp.<locals>.w<...>er at 0x0000018D5492A280>
# plus2      function                      <function <lambda> at 0x0000018D51CE2700>
# point      int                           83
# reduce     builtin_function_or_method    <built-in function reduce>
# result     list                          n=7

# %%
# 함수 선언
def grade(point) :
    if point >= 90 :
        print('A')
    elif point >= 80 :
        print('B')
    else :
        print('C')

# %%
# 함수 호출
grade(88)
# Out:
# B

# %%
grade(77)
# Out:
# C

# %% [markdown]
# ## 2. 파라미터와 아규먼트
# - 파라미터 : 함수를 선언할 때 호출하는 부분에서 보내주는 데이터를 받는 변수
# - 아규먼트 : 함수를 호출할 때 함수에 보내주는 데이터

# %% [markdown]
# ### 2.1 parameter and argument

# %%
def plus1(num1, num2) : # 파라미터
    print(num1+num2)

# %%
plus1(1, 2) # 아규먼트
# Out:
# 3

# %%
plus1(3, 4) # 아규먼트
# Out:
# 7

# %%
# 갯수를 다르게 써주면 에러
plus1(3,1,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-e1ffa89bb563> in <module>
#       1 # 갯수를 다르게 써주면 에러
# ----> 2 plus1(3,1,4)
#
# TypeError: plus1() takes 2 positional arguments but 3 were given

# %% [markdown]
# ### 2.2 default parameter

# %%
def plus2(num1, num2=10) : # default parameter
    print(num1+num2)
    
# 디폴트 파라미터 : 아규먼트를 안주면 기본적으로 num2=10이 들어간다.

# %%
plus2(1) # num2가 10이 들어가서 출력이 된다.
# Out:
# 11

# %%
def plus3(num1, num2=10, num3=20) : # default parameter
    print(num1+num2-num3)

# %% [markdown]
# ### 2.3 keyword argument

# %%
plus3(3, num3=100) # 키워드 아규먼트 : 원하는 아규먼트를 지정해서 바꿔준다
# Out:
# -87

# %% [markdown]
# ## 3. 리턴
# - 함수를 실행한 결과를 저장하고 싶을 때 사용
# - return

# %%
def plus(num1, num2) :
    print(num1+num2)
    return num1+num2

# %%
result = plus(1,2)
print(result) # 함수에서 반환해주는 값이 없기 때문에 None이 나옴, 이를 해결하기 위해 return을 쓴다.
# Out:
# 3
# 3

# %%
data1 = 'python'
result = data1.upper() # return이 있는 함수.
print(result)
# Out:
# PYTHON

# %%
data2 = [3, 1, 2]
result = data2.sort() # return이 없는 함수.
print(result)
# Out:
# None

# %%
# def grade(point) :
#     if point >= 90 :
#         result = 'A'
#     elif point > 80 :
#         result = 'B'
#     else :
#         result = 'C'
#     return result

def grade(point) :
    if point >= 90 :
        return 'A'
    elif point > 80 :
        return 'B'
    else :
        return 'C'

# %%
point = 92
result = grade(point)
print(result)
# Out:
# A

# %%
if result == 'A' :
    print('pass')
else :
    print('fail')
# Out:
# pass

# %%
# 함수에서 return 코드가 실행되면 무조건 함수의 코드 실행이 종료됨
# for문의 break같은 개념
def echo(msg) :
    if msg =='quit' :
        return
    print(msg)

# %%
echo('python')
# Out:
# python

# %%
echo('quit') # 중단

# %% [markdown]
# ## 4. \*args, \*\*kwargs
# - 함수를 호출할 때 아규먼트와 키워드아규먼트의 갯수를 특정지을 수 없을 때 사용

# %%
def plus(*args, **kwargs) :
    print(type(args), args)
    print(type(kwargs), kwargs)
    return sum(args) + sum(kwargs.values())

# %%
plus(1,2,3, num1=6, num2=3)
# Out:
# <class 'tuple'> (1, 2, 3)
# <class 'dict'> {'num1': 6, 'num2': 3}
# 15

# %%
def func(num1, num2, num3) :
    return num1 + num2 + num3


data = [1,2,3]
func(*data) #  = func(1,2,3)
# *이 없으면 list인 data가 num1으로 들어가고 num2, num3가 없어서 에러남
# *이 있으면 리스트안에 1,2,3이 하나하나씩 들어가서 num1, num2, num3가 채워짐
# Out:
# 6

# %%
data = {
    'num2' : 100,
    'num3' : 200,
}
func(1, **data) # func(1, num2=100, num3=200)
# Out:
# 301

# %% [markdown]
# ### Tip : magic command error
# - %reset
# - %time 등
# ```
# jupyter notebook error:root:invalud aliad:the name man can't be aliased because it is another magic command.
# ```
# - ipython 버전을 downgrade
#     - conda uninstall ipython
#     - conda install ipython=7.2.0
#     - conda install jupyter

# %% [markdown]
# ## 중간 Summary
# - 함수
#     - 중복되는 코드를 묶어서 효율적으로 코드를 작성하기 위해 사용
#     - 기본함수 : 선언(def), 호출(func_name())
#     - argument, parameter, keyword argument, default parameter
#     - return
#     - `*args`, `**kwargs`

# %% [markdown]
# ## 5. Docstring
# - 함수의 설명을 작성

# %%
def echo(msg) :
    "echo print msg" # docstring 작성
    print(msg)

# %%
def echo(msg) :
    """
    echo print msg
    echo func return its input argument
    The operation is :
        1. print msg parameter
        2. return msg parameter
    param : msg : str
    return : str
    """ # docstring 멀티 라인 작성 
    print(msg)

# %%
# docstring 확인 방법

# %%
echo?

# %%
echo??

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(msg)
#     echo print msg
#     echo func return its input argument
#     The operation is :
#         1. print msg parameter
#         2. return msg parameter
#     param : msg : str
#     return : str

# %%
print(echo.__doc__)
# Out:
#     echo print msg
#     echo func return its input argument
#     The operation is :
#         1. print msg parameter
#         2. return msg parameter
#     param : msg : str
#     return : str

# %% [markdown]
# ## 6. Scope 범위
# - 함수 안에서 선언되는 변수와 함수 밖에서 선언되는 변수의 범위가 다릅니다.
# - global(전역), local(지역)
# - 함수 안 : 지역, 함수 밖 : 전역
# - 전역변수는 안쓸 수 있으면 안쓰는게 좋다.

# %%
# global
gv = 10
def echo() :
    print(gv)
    return gv

print(echo(), gv)
# Out:
# 10
# 10 10

# %%
# local
gv = 10
def echo() :
    global gv
    gv = 100 # 전역으로 쓰겠다고 했으니 gv자체가 전역에서 100으로 바뀜
    print(gv)
echo()
gv # 100
# Out:
# 100
# 100

# %% [markdown]
# ## 7. inner function
# - 함수가 지역영역에 선언, 함수 안에 함수가 선언

# %%
def outer(a, b):
    
    def inner(c,d):
        return c+d
    
    return inner(a,b)

# %%
outer(1,2)
# Out:
# 3

# %%
# 지역함수는 전역영역에서 사용이 불가
inner(2,3) # 전역에서 지역을 쓸 수 없음.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-d41b1e47e8a2> in <module>
#       1 # 지역함수는 전역영역에서 사용이 불가
# ----> 2 inner(2,3) # 전역에서 지역을 쓸 수 없음.
#
# NameError: name 'inner' is not defined

# %%
def outer(a, b):
    
    def inner(c,d):
        print(a,b)
        return c+d
    
    return inner

# %%
outer(1,2)(3,4) # (1,2)는 의미없음
# outer(1,2)의 return이 inner임
# 즉 outer(1,2) = inner라서 inner(3,4) -> retun 3+4 = 7이 되는 것임
# Out:
# 1 2
# 7

# %% [markdown]
# ## 8. callback function
# - 함수를 아규먼트 파라미터로 설정해서 사용
# - 다른 함수에 대한 인수 역할
# - 일반적으로 프로그램에서 비동기 함수를 사용할 때 작동
#     - 비동기 함수는 때때로 루프와 같은 작업을 통해 동기화되지 않거나 비동기 적으로 작동하는 함수

# %%
def calc(func, a, b) :
    # code
    return func(a,b)

# %%
def plus(a,b) :
    return a + b

# %%
def minus(a,b) :
    return a - b

# %%
calc(plus, 1, 2) # 덧셈
# Out:
# 3

# %%
calc(minus, 1, 2) # 뺄셈
# Out:
# -1

# %%
def call_times(func):
    for i in range(3):
        func()

def print_hello():
    print('python love')
    
call_times(print_hello)
# Out:
# python love
# python love
# python love

# %% [markdown]
# ## 9. lambda 함수
# - 파라미터가 간단한 계산으로 리턴되는 함수 (삼항연산하고 비슷)
# - 함수를 선언하고 쓰면 그만큼의 메모리를 차지한다.
# - 그러나 람다를 쓰면 쓸때만 잠깐 나타났다 다시 사라져 메모리를 아낄 수 있다
# - 쓸 수 있으면 쓰는게 좋다 ( 복잡한 함수는 사용 불가 )

# %%
def plus(a,b) :
    return a + b

# %%
plus(1,2)
# Out:
# 3

# %%
plus2 = lambda a, b : a+b # lambda 변수 : 리턴
plus2(2,3)
# Out:
# 5

# %%
# calc(func, a, b)
calc(lambda a, b : a * b, 3, 4)
# Out:
# 12

# %% [markdown]
# ## 10. Map, Filter, Reduce
# - map : 순서가 있는 데이터 집합에서 모든 값에 함수를 적용시킨 결과를 출력
# - filter : 리스트 데이터에서 특정 조건에 맞는 value만 남기는 함수
# - reduce : 리스트 데이터를 처음부터 순서대로 특정 함수를 실행하여 결과를 누적시켜 주는 함수

# %% [markdown]
# map

# %%
ls = [1,2,3,4]

def odd_even(num) :
    return 'odd' if num % 2 else 'even'

odd_even(3), odd_even(4)
# Out:
# ('odd', 'even')

# %%
list(map(odd_even, ls))
# Out:
# ['odd', 'even', 'odd', 'even']

# %%
# input 함수로 구분자는 " "으로 여러개의 숫자를 입력 받습니다.
# str.split(" ") 리스트로 만들고
# 만들어진 리스트의 값들을 int 형변환

# %%
datas = input('insert numbers :')
# Out:
# insert numbers :10 20 30 10 40 20

# %%
type(datas), datas
# Out:
# (str, '10 20 30 10 40 20')

# %%
result = datas.split(" ")
result
# Out:
# ['10', '20', '30', '10', '40', '20']

# %%
result = list(map(int, result))
result
# Out:
# [10, 20, 30, 10, 40, 20]

# %% [markdown]
# Filter

# %%
ls = range(10)

# %%
# 홀수만 출력 (Ture인 것을 출력)
list(filter(lambda data : True if data % 2 else False,ls))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# reduce

# %%
from functools import reduce

# %%
ls = [3,1,2,4,5]
reduce(lambda x, y : x+y,ls)
# Out:
# 15

# %% [markdown]
# ## 11. Decorlator
# - 함수에서 코드를 바꾸지 않고 기능을 추가하거나 수정하고 싶을 때 사용하는 문법
#
# ```
# def a():
#     code_1
#     code_2
#     code_3
#
# def b():
#     code_1
#     code_4
#     code_3
# ```
# 위 함수에서 code_1과 code_3이 중복으로 쓰였다
#
# - 데코레이터의 사용
#
# ```
# def c(func) :
#
#     def wrapper(*args, **kwargs) :
#         code_1
#         func(*args, **kwargs)
#         code_3
#         return result
#
#     return wrapper
#
# @c
# def a() :
#     code_2
#
# @c
# def b() :
#     code_4
# ```

# %%
# a
def plus(a,b) :
    print('start')                   # code 1
    result = a + b                   # code 2
    print('result :{}'.format(result)) # code 3
    return result

# %%
# b
def minus(a,b) :
    print('start')                   # code 1
    result = a - b                   # code 4
    print('result :{}'.format(result)) # code 3
    return result

# %%
# c
def disp(func) :
    def wrapper(*args, **kwargs) :
        print('start')                   # code 1
        result = func(*args, **kwargs)   # code 2, code 4
        print('result : {}'.format(result)) # code 3
        return result
    return wrapper

# %%
@disp
def plus(a,b) :
    result = a + b
    return result

# %%
plus(1,2)
# Out:
# start
# result : 3
# 3
