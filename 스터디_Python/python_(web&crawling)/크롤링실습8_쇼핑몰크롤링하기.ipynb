# %%
import time
import selenium
import urllib.request
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import time
import os

# %%
class ShopInfo :
    
    @staticmethod
    def get_shop_info() :
        binary = 'c:\\chromedriver\\chromedriver.exe'
        global browser
        browser = webdriver.Chrome(binary)
        
        # 유신사 페이지 띄우기
        browser.get('https://search.musinsa.com/category/001001')
        time.sleep(5)

        # 이미지 소스
        source1 = browser.find_elements_by_xpath('//*[@id="searchList"]/li/div/div[1]/a/img')
#         //*[@id="searchList"]/li[10]/div[2]/div[1]/a/img
#         //*[@id="searchList"]/li[11]/div[4]/div[1]/a/img
        img_ls = []
        for i in source1 :
            img_ls.append(i.get_attribute('src'))
            time.sleep(0.1)
            
#         [ele.get_attribute('src') for ele in source1]
        print(img_ls)
        print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')

        # 브랜드이름 소스
        source2 = browser.find_elements_by_xpath('//*[@id="searchList"]/li/div/div/p[1]')
        brand_name = [ele.find_element_by_tag_name('a').text for ele in source2]
        print(brand_name)
        print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')


        # 상품이름 소스
        source3 = browser.find_elements_by_xpath('//*[@id="searchList"]/li/div/div/p[2]')
        item_name = [ele.find_element_by_tag_name('a').text for ele in source3]
        print(item_name)
        print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')


#         # 가격정보 소스
#         source4 = browser.find_elements_by_xpath('//*[@id="searchList"]/li/div/div/p[3]')
#         price_info = [ele.find_element_by_tag_name('p').text for ele in source4]
#         print(price_info)
#         print('@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@')
#             //*[@id="searchList"]/li[1]/div[3]/div[2]/p[5]/span[1]/span
#         # 이미지 스코어
#         source5 = browser.find_elements_by_xpath('//*[@id="searchList"]/li/div/div/p[5]/span[1]')
#         print(source5)
#         star_score = [ele.get_attribute('style') for ele in source5]
#         img_score = [ele.get_attribute('class') for ele in source5]
#         //*[@id="searchList"]/li[1]/div[3]/div[2]/p[5]/span[2]
        browser.close()
#         return img_ls, brand_name, item_name, price_info, star_score, img_score
    
    def get_img() :
        # 수집일 기준, 검색어폴더명으로 만들어주자
        today_time = dt.now()
        today = '{}{}{}'.format(today_time.year, today_time.month, today_time.day)
        if os.path.exists('C:\musinsa\{}_{}'.format(word, today)) :
            path = 'C:\musinsa\{}_{}'.format(word, today)
        else : 
            os.mkdir('C:\musinsa\{}_{}'.format(word, today))
            path = 'C:\musinsa\{}_{}'.format(word, today)
        
        ins = ShopInfo.get_shop_info()
        
        word = '무신사'
        time.sleep(1)
        for idx, images in enumerate(ins) :
            with urllib.request.urlopen(images) as f:
                time.sleep(1)
                with open('{}\{}_image{}.png'.format(path, word, idx), 'wb') as h :
                    titm.sleep(1)
                    img = f.read()
                    h.write(img)

        browser.close()

# %%
ShopInfo.get_shop_info()
# Out:
# ['https://image.msscdn.net/images/goods_img/20210316/1848166/1848166_3_125.jpg', 'https://image.msscdn.net/images/goods_img/20190327/996177/996177_3_125.jpg', 'https://image.msscdn.net/images/goods_img/20200424/1420730/1420730_1_125.jpg', 'https://image.msscdn.net/images/goods_img/20190327/996178/996178_3_125.jpg', 'https://image.msscdn.net/images/goods_img/20181112/903340/903340_7_125.jpg', 'https://image.msscdn.net/images/goods_img/20210407/1884943/1884943_1_125.jpg', 'https://image.msscdn.net/images/goods_img/20200428/1425234/1425234_2_125.jpg', 'https://image.msscdn.net/images/goods_img/20210407/1886950/1886950_1_125.jpg', 'https://image.msscdn.net/images/goods_img/20190404/1005683/1005683_5_125.jpg', 'https://image.msscdn.net/images/goods_img/20210311/1840098/1840098_1_125.jpg', 'https://image.msscdn.net/images/no_image_125.png', 'https://image.msscdn.net/images/no_image_125.png', 'https://image.msscdn.net/images/no_image_125.png', 'https://image.msscdn.net/images/no_image_125.p
# ...

# %%
help(browser)
# Out:
# Help on WebDriver in module selenium.webdriver.chrome.webdriver object:
#
# class WebDriver(selenium.webdriver.remote.webdriver.WebDriver)
#  |  WebDriver(executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |
#  |  Controls the ChromeDriver and allows you to drive the browser.
#  |
#  |  You will need to download the ChromeDriver executable from
#  |  http://chromedriver.storage.googleapis.com/index.html
#  |
#  |  Method resolution order:
#  |      WebDriver
#  |      selenium.webdriver.remote.webdriver.WebDriver
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, executable_path='chromedriver', port=0, options=None, service_args=None, desired_capabilities=None, service_log_path=None, chrome_options=None, keep_alive=True)
#  |      Creates a new instance of the chrome driver.
#  |
# ...
