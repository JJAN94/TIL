# %%
from bs4 import BeautifulSoup
import urllib.request # 웹상의 url을 파이썬이 인식할 수 있도록 해주는 모듈

# %%
def T1() :
    list_url ='https://naver.com'
    # 사람이 알아볼수 있는 위의 url을 파이썬이 알아 볼 수 있도록 해주는 첫번째 작업
    url = urllib.request.Request(list_url)
    print(url, type(url))

    # url를 읽어서 리턴
    result = urllib.request.urlopen(url).read().decode("utf-8")
    print(result)

# euc-kr    

def T2() :
    list_url ='http://www.daum.net'
    # 사람이 알아볼수 있는 위의 url을 파이썬이 알아 볼 수 있도록 해주는 첫번째 작업
    url = urllib.request.Request(list_url) 
    print(url, type(url))

    # url를 읽어서 리턴
    result = urllib.request.urlopen(url).read().decode("utf-8")
    print(result)

def T3() :
    list_url ='https://naver.com'
    # 사람이 알아볼수 있는 위의 url을 파이썬이 알아 볼 수 있도록 해주는 첫번째 작업
    url = urllib.request.Request(list_url) 
    # print(url, type(url))

    # url를 읽어서 리턴
    result = urllib.request.urlopen(url).read().decode("utf-8")
    # print(result, type(result))
    soup = BeautifulSoup(result, 'html.parser')
    print(soup.h1.get_text())

# %%
T1()
# Out:
# <urllib.request.Request object at 0x000001754DA3F370> <class 'urllib.request.Request'>
#
# ...

# %%
T2()
# Out:
# <urllib.request.Request object at 0x000001754DA3F1C0> <class 'urllib.request.Request'>
# ...

# %%
T3()
# Out:
# <!DOCTYPE html>
# ...
